# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sb

# %%
df = pd.read_csv('../data/top-500-movies.csv')
df
# Out:
#      rank release_date                                        title  \
# 0       1   2019-04-23                            Avengers: Endgame
# 1       2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2       3   2015-04-22                      Avengers: Age of Ultron
# 3       4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4       5   2018-04-25                       Avengers: Infinity War
# ..    ...          ...                                          ...
# 495   496   2013-02-06                       A Good Day to Die Hard
# 496   497   2004-04-09                                    The Alamo
# 497   498   1995-12-22                             Cutthroat Island
# 498   499   2013-12-19              The Secret Life of Walter Mitty
# 499   500   2023-03-09                                           65
#
#                                                    url  production_cost  \
# 0           /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# ...

# %%
df = df.drop(['url', 'rank', 'release_date'], axis=1)

# %%
df.fillna(df.mean(numeric_only=True).round(), inplace=True)

# %%
df['domestic_gross'].replace(0, df['domestic_gross'].mean(), inplace=True)
df['worldwide_gross'].replace(0, df['worldwide_gross'].mean(), inplace=True)
# Out:
# /var/folders/_k/9pcm610n0sb_j9n64tc8zgcw0000gn/T/ipykernel_69489/751040058.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['domestic_gross'].replace(0, df['domestic_gross'].mean(), inplace=True)
# /var/folders/_k/9pcm610n0sb_j9n64tc8zgcw0000gn/T/ipykernel_69489/751040058.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df = df.loc[df['mpaa'] != 'Unrated', :]

# %%
df['year'] = df['year'].astype(int)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                            title  production_cost  \
# 0                              Avengers: Endgame        400000000
# 1    Pirates of the Caribbean: On Stranger Tides        379000000
# 2                        Avengers: Age of Ultron        365000000
# 3           Star Wars Ep. VII: The Force Awakens        306000000
# 4                         Avengers: Infinity War        300000000
# ..                                           ...              ...
# 494                              The Incredibles         92000000
# 495                       A Good Day to Die Hard         92000000
# 496                                    The Alamo         92000000
# 497                             Cutthroat Island         92000000
# 498              The Secret Life of Walter Mitty         91000000
#
#      domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 0       858373000.0     2.797801e+09      357115007.0  PG-13     Action
# ...

# %%
df.dtypes
# Out:
# title               object
# production_cost      int64
# domestic_gross     float64
# worldwide_gross    float64
# opening_weekend    float64
# mpaa                object
# genre               object
# theaters           float64
# runtime            float64
# year                 int64
# dtype: object

# %%
df.isna().sum()
# Out:
# title              0
# production_cost    0
# domestic_gross     0
# worldwide_gross    0
# opening_weekend    0
# mpaa               0
# genre              0
# theaters           0
# runtime            0
# year               0
# dtype: int64

# %%
df.describe()
# Out:
#        production_cost  domestic_gross  worldwide_gross  opening_weekend  \
# count     4.910000e+02    4.910000e+02     4.910000e+02     4.910000e+02
# mean      1.494872e+08    1.753206e+08     4.779511e+08     5.429206e+07
# std       4.759424e+07    1.394589e+08     3.830213e+08     4.562877e+07
# min       9.100000e+07    3.114340e+05     7.561500e+04     4.855800e+04
# 25%       1.100000e+08    7.872882e+07     2.186231e+08     2.467904e+07
# 50%       1.400000e+08    1.385409e+08     3.748258e+08     4.363974e+07
# 75%       1.750000e+08    2.191196e+08     6.484352e+08     6.770120e+07
# max       4.000000e+08    9.366622e+08     2.910371e+09     3.571150e+08
#
#           theaters     runtime         year
# count   491.000000  491.000000   491.000000
# mean   3659.775967  121.865580  2011.358452
# std     539.291514   22.303341     6.533261
# min      30.000000   76.000000  1991.000000
# 25%    3394.000000  105.000000  2007.000000
# ...

# %%
df_corr = df.corr(numeric_only = True)

# %%
sb.heatmap(df_corr, annot = True, vmin = -1, vmax = 1, cmap = 'coolwarm', linecolor='white', linewidths=0.5, fmt='.2f')
plt.show()

# %%
X = df.loc[:, ['production_cost', 'opening_weekend', 'mpaa', 'genre', 'theaters', 'runtime', 'year']]
X
# Out:
#      production_cost  opening_weekend   mpaa      genre  theaters  runtime  \
# 0          400000000      357115007.0  PG-13     Action    4662.0    181.0
# 1          379000000       90151958.0  PG-13  Adventure    4164.0    136.0
# 2          365000000      191271109.0  PG-13     Action    4276.0    141.0
# 3          306000000      247966675.0  PG-13  Adventure    4134.0    136.0
# 4          300000000      257698183.0  PG-13     Action    4474.0    156.0
# ..               ...              ...    ...        ...       ...      ...
# 494         92000000       70467623.0     PG  Adventure    3933.0    115.0
# 495         92000000       24834845.0      R     Action    3555.0     98.0
# 496         92000000        9124701.0  PG-13    Western    2609.0    137.0
# 497         92000000        2371415.0  PG-13  Adventure    1619.0    122.0
# 498         91000000       12765508.0     PG  Adventure    2922.0    114.0
#
#      year
# 0    2019
# 1    2011
# 2    2015
# 3    2015
# ...

# %%
Y = df.loc[:, 'domestic_gross':'worldwide_gross']
Y
# Out:
#      domestic_gross  worldwide_gross
# 0       858373000.0     2.797801e+09
# 1       241071802.0     1.045714e+09
# 2       459005868.0     1.395317e+09
# 3       936662225.0     2.064616e+09
# 4       678815482.0     2.048360e+09
# ..              ...              ...
# 494     261441092.0     6.314411e+08
# 495      67349198.0     3.042492e+08
# 496      22406362.0     2.391136e+07
# 497      10017322.0     1.851732e+07
# 498      58236838.0     1.878612e+08
#
# [491 rows x 2 columns]

# %% [markdown]
# #### 레이블 인코딩

# %%
from sklearn.preprocessing import LabelEncoder
from pandas.api.types import is_integer_dtype, is_float_dtype, is_object_dtype

# %%
X_new = pd.DataFrame()

for col in X:
    if is_integer_dtype(X[col]) : 
        X_new[col] = X[col]
    elif is_float_dtype(X[col]) :
        X_new[col] = X[col]
    elif is_object_dtype(X[col]) :
        encoder = LabelEncoder()
        X_new[col] = encoder.fit_transform(X[col])

# %%
X_new
# Out:
#      production_cost  opening_weekend  mpaa  genre  theaters  runtime  year
# 0          400000000      357115007.0     2      0    4662.0    181.0  2019
# 1          379000000       90151958.0     2      1    4164.0    136.0  2011
# 2          365000000      191271109.0     2      0    4276.0    141.0  2015
# 3          306000000      247966675.0     2      1    4134.0    136.0  2015
# 4          300000000      257698183.0     2      0    4474.0    156.0  2018
# ..               ...              ...   ...    ...       ...      ...   ...
# 494         92000000       70467623.0     1      1    3933.0    115.0  2004
# 495         92000000       24834845.0     3      0    3555.0     98.0  2013
# 496         92000000        9124701.0     2      9    2609.0    137.0  2004
# 497         92000000        2371415.0     2      1    1619.0    122.0  1995
# 498         91000000       12765508.0     1      1    2922.0    114.0  2013
#
# [491 rows x 7 columns]

# %% [markdown]
# #### K-Means 클러스터링

# %%
from sklearn.cluster import KMeans

# %%
print('최적의 K값 결정')
max_k = min(10, X_new.shape[0])
print(f'데이터 개수: {X_new.shape[0]} / 최대 클러스터 개수: {max_k}')
# Out:
# 최적의 K값 결정
# 데이터 개수: 491 / 최대 클러스터 개수: 10

# %%
wcss = []
for k in range(1, max_k + 1):
    kmeans = KMeans(n_clusters=k, random_state=4, n_init=10)
    kmeans.fit(X_new)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, max_k + 1), wcss)
plt.title('The Elbow Method')
plt.xlabel('# of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# 최적의 K 결정
if max_k == 3 :
    if (wcss[0] - wcss[1]) / (wcss[1] - wcss[2]) >= 2 :
        k = 2
    else : 
        if wcss[0] / min(wcss) >= 2 :
            k = 3
        else :
            k = 1
elif max_k == 2 :
    if (wcss[0] - wcss[1]) / wcss[1] >= 1 :
        k = 2 
    else :
        k = 1
else:
    best = []
    cnt = 0
    for a in range(2, max_k - 1) :
        if wcss[a - 1] - wcss[a + 1] != 0 :
            new_delta = (wcss[a - 2] - wcss[a]) / (wcss[a - 1] - wcss[a + 1])
            if new_delta >= 2 :
                best.append(a)
            else :
                if cnt == 0 :
                    best.append(a)
                    cnt += 1
                else :
                    continue
    if len(best) != 0 :
         k = max(best)
    else : 
        k = max_k
print(f'🎯 최적의 클러스터 개수: {k}개')
# Out:
# 🎯 최적의 클러스터 개수: 3개

# %%
kmeans = KMeans(n_clusters=k, random_state=4)
df['Group'] = kmeans.fit_predict(X_new)
print('✅ 그룹 정보가 저장되었습니다.')
# Out:
# ✅ 그룹 정보가 저장되었습니다.

# %%
df
# Out:
#                                            title  production_cost  \
# 0                              Avengers: Endgame        400000000
# 1    Pirates of the Caribbean: On Stranger Tides        379000000
# 2                        Avengers: Age of Ultron        365000000
# 3           Star Wars Ep. VII: The Force Awakens        306000000
# 4                         Avengers: Infinity War        300000000
# ..                                           ...              ...
# 494                              The Incredibles         92000000
# 495                       A Good Day to Die Hard         92000000
# 496                                    The Alamo         92000000
# 497                             Cutthroat Island         92000000
# 498              The Secret Life of Walter Mitty         91000000
#
#      domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 0       858373000.0     2.797801e+09      357115007.0  PG-13     Action
# ...

# %%
df.rename(columns={'title':'제목', 'production_cost':'제작 비용 ($)', 'domestic_gross':'북미 박스오피스 수익 ($)', 'worldwide_gross':'전세계 박스오피스 수익 ($)',
                   'opening_weekend':'개봉 주말 수익 ($)', 'mpaa':'상영 등급', 'genre':'장르', 'theaters':'상영관 수', 'runtime':'상영 시간', 'year':'개봉 연도',
                    'Group':'영화 유형'}, inplace=True)

# %%
df.to_csv('../data/new_movie.csv', index=0)
